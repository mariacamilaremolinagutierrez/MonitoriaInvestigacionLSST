# %%
# %pylab inline
from astropy.io import fits
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
path_imagenes = '../imagenes_alineadas/graficas/'

# %%
visita = fits.open('../imagenes_alineadas/sustraccion_4D/sustraccion_4D.fits')

imagen = visita[0].data

shape_imagen = shape(imagen)
print shape_imagen
# Out:
# (1200, 1200)

# %%
#Imagen vs Media
#Grafico solo los puntos arriba de la media

media = average(imagen)
print media

grafica_media = zeros((shape_imagen[0], shape_imagen[1]))

for fila in range(shape_imagen[0]):
    for columna in range(shape_imagen[1]):

        pixel = imagen[fila][columna]

        if (pixel > media):
            grafica_media[fila][columna] = pixel
            
hdu = fits.PrimaryHDU(grafica_media)
hdu.writeto(path_imagenes+'media.fits')
# Out:
# 171591.65962

# %%
fig = figure(figsize=(14,14))
imshow(grafica_media, cmap='gray',vmin=0,vmax=7)
colorbar()
savefig(path_imagenes+'media.png', bbox_inches='tight')
show()
close()

# %%
#Imagen vs Mediana
#Grafico solo los puntos arriba de la mediana

mediana = median(imagen)
print mediana

grafica_mediana = zeros((shape_imagen[0], shape_imagen[1]))

for fila in range(shape_imagen[0]):
    for columna in range(shape_imagen[1]):

        pixel = imagen[fila][columna]

        if (pixel > mediana):
            grafica_mediana[fila][columna] = pixel
            
hdu = fits.PrimaryHDU(grafica_mediana)
hdu.writeto(path_imagenes+'mediana.fits')
# Out:
# 171039.703408

# %%
fig = figure(figsize=(14,14))
imshow(grafica_mediana, cmap='gray',vmin=0,vmax=7)
colorbar()
savefig(path_imagenes+'mediana.png', bbox_inches='tight')
show()
close()
